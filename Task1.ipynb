# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth2015/CS203_Lab_3/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![checking_py.png](data:image/png;base64,...)

# %% [markdown]
# ![editedbash.png](data:image/png;base64,...)

# %% [markdown]
# ![installdone.png](data:image/png;base64,...)

# %% [markdown]
# ![installing openssl.png](data:image/png;base64,...)

# %% [markdown]
# ![pip.png](data:image/png;base64,...)

# %% [markdown]
# ![python download.png](data:image/png;base64,...)

# %% [markdown]
# ![python_list.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_20_26.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_22_59.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_23_25.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_24_49.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_25_09.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_38_57.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_18_56_05.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_19_04_33.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_19_14_58.png](data:image/png;base64,...)

# %% [markdown]
# ![VirtualBox_praneel_26_01_2025_19_19_53.png](data:image/png;base64,...)
